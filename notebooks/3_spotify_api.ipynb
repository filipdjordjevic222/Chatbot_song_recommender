# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from dotenv import load_dotenv
import os
import pandas as pd
import time
from datetime import datetime

# %%
load_dotenv() # load environment variables

client_id = os.getenv('SPOTIFY_CLIENT_ID')
client_secret = os.getenv('SPOTIFY_CLIENT_SECRET')

# spotipy setup
client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager, requests_timeout=20)

# %%
try:
    sp = spotipy.Spotify(
        client_credentials_manager=client_credentials_manager,
        requests_timeout=10
    )
    # Test the connection
    sp.search(q='test', limit=1)
    print("Spotify connection successful!")
except Exception as e:
    print(f"Authentication error: {e}")
# Out:
# Spotify connection successful!

# %%
#r = sp.search(q='Dont stop me now', type='track', limit=1)
#  r
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=1&query=Dont%20stop%20me%20now&type=track',
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?offset=1&limit=1&query=Dont%20stop%20me%20now&type=track',
#   'offset': 0,
#   'previous': None,
#   'total': 1000,
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#        'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#        'id': '1dfeR4HaWDbWqFHLkxsg1d',
#        'name': 'Queen',
#        'type': 'artist',
#        'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2yuTRGIackbcReLUXOYBqU'},
#      'href': 'https://api.spotify.com/v1/albums/2yuTRGIackbcReLUXOYBqU',
#      'id': '2yuTRGIackbcReLUXOYBqU',
#      'images': [{'height': 640,
#        'width': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737c39dd133836c2c1c87e34d6'},
#       {'height': 300,
#        'width': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027c39dd133836c2c1c87e34d6'},
#       {'height': 64,
#        'width': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517c39dd133836c2c1c87e34d6'}],
#      'is_playable': True,
#      'name': 'Jazz (2011 Remaster)',
#      'release_date': '1978-11-10',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:2yuTRGIackbcReLUXOYBqU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#       'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#       'id': '1dfeR4HaWDbWqFHLkxsg1d',
#       'name': 'Queen',
#       'type': 'artist',
#       'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 209413,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM71029610'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5T8EDUDqKcs6OSOwEsfqG7'},
#     'href': 'https://api.spotify.com/v1/tracks/5T8EDUDqKcs6OSOwEsfqG7',
#     'id': '5T8EDUDqKcs6OSOwEsfqG7',
#     'is_local': False,
#     'is_playable': True,
#     'name': "Don't Stop Me Now - Remastered 2011",
#     'popularity': 81,
#     'preview_url': None,
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:5T8EDUDqKcs6OSOwEsfqG7'}]}}

# %%
genres = sp.artist('1dfeR4HaWDbWqFHLkxsg1d')
genres['genres']
# Out:
# ['classic rock', 'glam rock', 'rock']

# %%
# Load million songs dataset
million_songs_df = pd.read_csv('../data/3_combined_clean_dataset.csv')

# Process settings
BATCH_SIZE = 25
SLEEP_TIME = 45

# Get the last processed index from existing backup file
backup_file = '../data/4_spotify_million_tracks.csv'
if os.path.exists(backup_file):
    processed_df = pd.read_csv (backup_file) #,
        #quoting=csv.QUOTE_MINIMAL,  # Handle quotes more carefully
        #escapechar='\\',  # Use backslash as escape character
        #encoding='utf-8'  # Explicitly specify encoding)
    

    start_index = len(processed_df)
    print(f'Resuming from index {start_index}')
else:
    start_index = 0
    print('Starting new processing')

# Process in batches
for start_idx in range(start_index, len(million_songs_df), BATCH_SIZE):
    batch = million_songs_df.iloc[start_idx:start_idx + BATCH_SIZE]
    tracks_data = []
    
    print(f'\nProcessing batch {start_idx//BATCH_SIZE + 1} of {len(million_songs_df)//BATCH_SIZE + 1}')
    print(f'Processing rows {start_idx} to {min(start_idx + BATCH_SIZE, len(million_songs_df))}')
    
    for i, row in batch.iterrows():
        try:
            # Use 'title' instead of 'song_title'
            results = sp.search(q=f'track:{row["title"]} artist:{row["artist"]}', type='track', limit=1)
            
            if results['tracks']['items']:
                track = results['tracks']['items'][0]
                artist_id = track['artists'][0]['id']
                genres = sp.artist(artist_id)['genres']
                print("Genres: ", genres)

                # Update track_data dictionary to use correct column names
                track_data = {
                    'original_title': row['title'],  # Changed from 'song_title'
                    'original_artist': row['artist'],
                    'spotify_title': track['name'],
                    'spotify_artist': track['artists'][0]['name'],
                    'album': track['album']['name'],
                    'release_date': track['album']['release_date'],
                    'popularity': track['popularity'],
                    'duration_ms': track['duration_ms'],
                    'explicit': track['explicit'],
                    'album_cover': track['album']['images'][0]['url'] if track['album']['images'] else None,
                    'genres': genres if genres else None
                }
                tracks_data.append(track_data)
                
        except Exception as e:
            print(f'Error processing track {row["title"]}: {str(e)}')  # Changed from 'song_title'
            continue

    # Save batch results
    if tracks_data:
        temp_df = pd.DataFrame(tracks_data)
        temp_df.to_csv(backup_file, 
                    mode='a', 
                    header=not os.path.exists(backup_file), 
                    index=False)
        
        timestamp = datetime.now().strftime('%H:%M:%S')
        print(f'Batch completed at {timestamp}')
        print(f'Processed {len(tracks_data)} tracks in this batch')
        print(f'Total tracks processed: {start_idx + len(tracks_data)}')
        print(f'Last track processed: {row["title"]}')
        print(f'Last track genres: {genres if genres else "No genres found"}')
        
        if start_idx + BATCH_SIZE < len(million_songs_df):  # don't sleep after the last batch
            print(f'Sleeping for {SLEEP_TIME} seconds...')
            print('-' * 50)
            time.sleep(SLEEP_TIME)

print(f'\nAll batches processed!')
print(f'Final total tracks processed: {start_idx + len(tracks_data)}')
# Out:
# Resuming from index 7731
#
# Processing batch 310 of 402
# Processing rows 7731 to 7756
# Genres:  ['cool jazz', 'jazz vibraphone', 'latin jazz']
# Genres:  ['lovers rock']
# Genres:  ['acoustic blues', 'blues', 'country blues', 'gospel blues', 'texas blues', 'traditional blues']
# Genres:  ['experimental', 'experimental vocal', 'industrial', 'laboratorio']
# Genres:  []
# Genres:  ['gothic black metal', 'gothic metal', 'melodic death metal', 'metal', 'portuguese black metal', 'portuguese metal', 'portuguese rock', 'power metal']
# Genres:  ['new age']
# Genres:  ['banjo', 'country gospel', 'western swing']
# Genres:  ['atmospheric post-metal', 'drone metal', 'post-metal', 'sludge metal']
# Genres:  ['ccm', 'christian alternative rock', 'christian music', 'christian rock']
# Genres:  ['detroit hip hop', 'kansas city hip hop', 'pop rap']
# Genres:  ['acoustic blues', 'blues', 'country blues', 'harmonica blues', 'piedmont blues', 'traditional blues']
# Genres:  ['grunge pop']
# Genres:  []
# Genres:  ['big band', "man's orchestra"]
# Genres:  ['atl hip hop', 'dirty south rap']
# Batch completed at 09:49:48
# Processed 16 tracks in this batch
# Total tracks processed: 7747
# Last track processed: follow the light
# Last track genres: ['atl hip hop', 'dirty south rap']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 311 of 402
# Processing rows 7756 to 7781
# Genres:  ['chicago blues', 'country blues', 'harmonica blues']
# Genres:  ['deep east coast hip hop', 'hardcore hip hop']
# Genres:  ['british blues']
# Genres:  ['footwork', 'ghettotech']
# Genres:  ['vintage chanson']
# Genres:  []
# Genres:  []
# Genres:  []
# Genres:  []
# Genres:  ['easy listening', 'honky-tonk piano', 'nashville sound']
# Genres:  ['chicago rap', 'hip hop', 'rap']
# Genres:  ['pop romantico']
# Genres:  []
# Batch completed at 09:50:36
# Processed 13 tracks in this batch
# Total tracks processed: 7769
# Last track processed: alone together live acoustic
# Last track genres: No genres found
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 312 of 402
# Processing rows 7781 to 7806
# Genres:  ['bossa nova', 'jazz accordion', 'mpb', 'samba', 'samba-jazz', 'velha guarda']
# Genres:  ['album rock', 'classic rock', 'country rock', 'glam metal', 'hard rock', 'mellow gold', 'rock', 'singer-songwriter', 'soft rock', 'southern rock']
# Genres:  ['kizomba', 'kizomba antigas', 'zouk']
# Genres:  ['bolero', 'bolero mexicano', 'tropical']
# Genres:  ['dance pop', 'pop']
# Genres:  ['glitch pop']
# Genres:  []
# Genres:  ['german alternative rap', 'german pop', 'hamburg hip hop', 'oldschool deutschrap']
# Genres:  ['classical', 'late romantic era', 'norwegian classical']
# Genres:  ['praise']
# Genres:  []
# Genres:  []
# Genres:  ['spacegrunge']
# Genres:  []
# Genres:  ['acoustic pop', 'neo mellow', 'pop rock']
# Genres:  ['acoustic pop', 'neo mellow']
# Genres:  ['album rock', 'classic rock', 'hard rock', 'mellow gold', 'new wave', 'new wave pop', 'power pop', 'soft rock']
# Batch completed at 09:51:25
# Processed 17 tracks in this batch
# Total tracks processed: 7798
# Last track processed: dance of romance
# Last track genres: ['album rock', 'classic rock', 'hard rock', 'mellow gold', 'new wave', 'new wave pop', 'power pop', 'soft rock']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 313 of 402
# Processing rows 7806 to 7831
# Genres:  ['rock drums', 'soft rock']
# Genres:  ['blues', 'blues rock', 'electric blues', 'modern blues', 'modern blues rock']
# Genres:  ['bolero mexicano']
# Genres:  ['lovers rock', 'uk reggae']
# Genres:  ['alternative rock', 'punk', 'rock']
# Genres:  ['praise']
# Genres:  ['art rock', 'classic rock', 'glam rock', 'permanent wave', 'rock']
# Genres:  []
# Genres:  ['bhangra', 'classic bhangra']
# Genres:  ['alternative rock', 'art rock', 'melancholia', 'oxford indie', 'permanent wave', 'rock']
# Genres:  ['atmospheric doom', 'dutch metal', 'gothic metal', 'gothic symphonic metal', 'symphonic metal']
# Genres:  ['turkish pop']
# Genres:  ['sleaze rock']
# Batch completed at 09:52:13
# Processed 13 tracks in this batch
# Total tracks processed: 7819
# Last track processed: another lover
# Last track genres: ['sleaze rock']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 314 of 402
# Processing rows 7831 to 7856
# Genres:  ['horror punk']
# Genres:  ['australian dance', 'classic hardstyle', 'euphoric hardstyle', 'gabber', 'happy hardcore']
# Genres:  []
# Genres:  ['chicago blues', 'delta blues', 'piano blues']
# Genres:  ['qawwali', 'sufi']
# Genres:  ['argentine reggae', 'argentine rock', 'post-punk argentina', 'rock nacional', 'ska argentino']
# Genres:  ['east coast hip hop', 'golden age hip hop', 'hip hop', 'old school hip hop']
# Genres:  ['mambo', 'salsa', 'salsa colombiana']
# Genres:  []
# Genres:  ['east coast hip hop', 'hip hop', 'new jersey rap']
# Genres:  ['punk', 'skate punk', 'socal pop punk']
# Genres:  ['dance pop', 'pop']
# Genres:  ['polish contemporary classical']
# Genres:  ['orchestral soundtrack', 'soundtrack']
# Genres:  ['swedish synth']
# Genres:  ['detroit hip hop', 'hip hop', 'rap']
# Genres:  ['g funk', 'west coast rap']
# Genres:  ['ethereal wave', 'neoclassical darkwave']
# Genres:  ['album rock', 'classic rock', 'mellow gold', 'rock', 'singer-songwriter', 'soft rock', 'yacht rock']
# Genres:  ['southern rock', 'texas blues']
# Batch completed at 09:53:03
# Processed 20 tracks in this batch
# Total tracks processed: 7851
# Last track processed: see what tomorrow brings
# Last track genres: ['southern rock', 'texas blues']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 315 of 402
# Processing rows 7856 to 7881
# Genres:  []
# Genres:  ['greek pop', 'laiko']
# Genres:  ['classic venezuelan pop', 'gaita zuliana']
# Genres:  ['humppa']
# Genres:  ['canadian pop']
# Genres:  ['british blues', 'progressive rock', 'proto-metal']
# Genres:  ['austin singer-songwriter']
# Genres:  ['brostep', 'classic dubstep', 'filthstep', 'glitch hop']
# Genres:  []
# Genres:  ['modern ska punk', 'pop punk', 'punk', 'ska', 'ska punk', 'skate punk']
# Genres:  ['alternative dance', 'alternative rock', 'dance-punk', 'indie rock', 'indietronica', 'modern rock', 'neo-synthpop', 'new rave']
# Genres:  ['nashville sound']
# Genres:  ['tejano']
# Genres:  ['boogaloo']
# Genres:  ['britpop', 'dance rock', 'grebo']
# Genres:  ['irish country', 'irish folk']
# Genres:  ['bossa nova', 'mpb', 'samba', 'velha guarda']
# Genres:  ['abstract hip hop', 'alternative hip hop', 'conscious hip hop']
# Genres:  ['deep ragga', 'lovers rock']
# Batch completed at 09:53:52
# Processed 19 tracks in this batch
# Total tracks processed: 7875
# Last track processed: blowup outtake
# Last track genres: ['deep ragga', 'lovers rock']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 316 of 402
# Processing rows 7881 to 7906
# Genres:  ['british blues', 'proto-metal']
# Genres:  ['classic australian country', 'merseybeat', 'rock-and-roll', 'yodeling']
# Genres:  []
# Genres:  ['argentine rock', 'latin alternative', 'latin rock', 'rock en espanol']
# Genres:  ['irish folk', 'irish pub song']
# Genres:  ['big beat', 'breakbeat', 'electronica']
# Genres:  ['carnaval cadiz', 'pop flamenco', 'rumba', 'spanish pop']
# Genres:  ['charanga', 'salsa']
# Genres:  []
# Genres:  ['country blues', 'memphis blues', 'traditional blues']
# Genres:  ['dance pop', 'pop', 'urban contemporary']
# Genres:  ['adult standards', 'easy listening', 'lounge', 'vocal jazz']
# Genres:  ['kirtan', 'meditation', 'world devotional']
# Genres:  ['ccm', 'christian alternative rock', 'christian music', 'christian rock']
# Genres:  ['classic greek pop']
# Genres:  ['classic soundtrack', 'deep soundtrack']
# Genres:  []
# Genres:  ['banda', 'grupera', 'musica mexicana', 'norteno', 'tejano']
# Batch completed at 09:54:41
# Processed 18 tracks in this batch
# Total tracks processed: 7899
# Last track processed: la valse de la cour bof mayerling
# Last track genres: ['banda', 'grupera', 'musica mexicana', 'norteno', 'tejano']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 317 of 402
# Processing rows 7906 to 7931
# Genres:  ['album rock', 'classic rock', 'detroit rock', 'glam metal', 'glam rock', 'hard rock', 'metal', 'protopunk', 'rock']
# Genres:  ['greek metal', 'melodic black metal', 'slayer', 'symphonic black metal']
# Genres:  ['big beat', 'breakbeat', 'drum and bass', 'jungle']
# Genres:  ['classic country pop', 'honky tonk', 'western swing']
# Genres:  ['dance pop', 'r&b', 'urban contemporary']
# Genres:  []
# Genres:  ['glam rock', 'hard rock', 'rock']
# Genres:  ['argentine rock', 'latin alternative', 'latin rock', 'post-punk argentina', 'rock en espanol']
# Genres:  ['alternative metal', 'nu metal', 'pop punk', 'pop rock', 'rap rock', 'socal pop punk']
# Genres:  ['irish pub song']
# Genres:  ['lilith', 'new wave pop', 'permanent wave', 'pop rock', 'swedish pop']
# Genres:  []
# Genres:  ['reggae', 'roots reggae']
# Genres:  []
# Genres:  ['rumba', 'rumba catalana']
# Batch completed at 09:55:29
# Processed 15 tracks in this batch
# Total tracks processed: 7921
# Last track processed: im your money 12 extended version 2006 digital remaster
# Last track genres: ['rumba', 'rumba catalana']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 318 of 402
# Processing rows 7931 to 7956
# Genres:  ['modern rock', 'post-grunge']
# Genres:  ['bronx hip hop', 'east coast hip hop', 'jazz rap']
# Genres:  ['cool jazz', 'jazz drums']
# Genres:  ['melodic metalcore']
# Genres:  ['electric blues', 'memphis soul', 'soul blues', 'southern soul']
# Genres:  ['praise']
# Genres:  ['orchestral soundtrack', 'soundtrack']
# Genres:  ['greek pop', 'laiko']
# Genres:  ['deep christian rock']
# Genres:  []
# Genres:  ['tejano']
# Genres:  []
# Genres:  ['post-hardcore', 'screamo', 'uk post-hardcore']
# Genres:  []
# Genres:  ['classic progressive house']
# Genres:  ['greek pop', 'laiko']
# Genres:  ['entehno', 'greek pop', 'laiko']
# Genres:  ['album rock', 'blues rock', 'british blues', 'classic rock', 'hard rock']
# Genres:  ['jazz guitar trio']
# Genres:  ['neo soul', 'pop', 'r&b']
# Genres:  ['reggaeton', 'salsa choke', 'urbano latino']
# Genres:  ['atl hip hop', 'old school atlanta hip hop']
# Genres:  ['classic finnish pop', 'classic iskelma']
# Batch completed at 09:56:19
# Processed 23 tracks in this batch
# Total tracks processed: 7954
# Last track processed: vankina vapauden
# Last track genres: ['classic finnish pop', 'classic iskelma']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 319 of 402
# Processing rows 7956 to 7981
# Genres:  ['modern blues']
# Genres:  ['alternative rock', 'punk', 'rock']
# Genres:  ['brit funk']
# Genres:  ['grindcore']
# Genres:  ['big beat', 'breakbeat', 'dance rock', 'hardcore techno', 'rave']
# Genres:  ['rock drums', 'soft rock']
# Genres:  ['early us punk', 'glam punk', 'glam rock', 'protopunk', 'punk']
# Genres:  ['jazz trombone', 'space age pop']
# Genres:  []
# Genres:  ['screamo']
# Genres:  []
# Genres:  ['avant-garde jazz', 'contemporary post-bop', 'jazz', 'jazz fusion', 'jazz guitar']
# Genres:  []
# Genres:  ['string band']
# Batch completed at 09:57:08
# Processed 14 tracks in this batch
# Total tracks processed: 7970
# Last track processed: the magic violin
# Last track genres: ['string band']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 320 of 402
# Processing rows 7981 to 8006
# Genres:  ['aggrotech', 'industrial metal', 'steampunk']
# Genres:  ['gbvfi', 'post-hardcore']
# Genres:  []
# Genres:  ['boogaloo', 'jazz puertorriqueno', 'salsa', 'salsa puertorriquena']
# Genres:  ['vintage chanson']
# Genres:  []
# Genres:  ['greek pop', 'laiko']
# Genres:  ['deep smooth jazz', 'jazz flute', 'smooth jazz']
# Genres:  ['alternative country']
# Genres:  ['classic country pop']
# Genres:  ['polish contemporary classical']
# Genres:  []
# Genres:  ['pop flamenco', 'rumba']
# Genres:  ['christian alternative rock', 'christian music']
# Genres:  ['austin americana']
# Genres:  []
# Genres:  []
# Genres:  ['experimental rock', 'japanoise', 'math rock', 'noise rock', 'noisecore']
# Genres:  []
# Batch completed at 09:57:58
# Processed 19 tracks in this batch
# Total tracks processed: 8000
# Last track processed: up on the house top
# Last track genres: No genres found
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 321 of 402
# Processing rows 8006 to 8031
# Genres:  ['ghettotech']
# Genres:  ['chanson', 'french pop', 'french rock', 'nouvelle chanson francaise']
# Genres:  ['corrosion']
# Genres:  ['black metal', 'death metal', 'groove metal', 'metal', 'pagan black metal', 'polish black metal', 'polish death metal', 'polish metal']
# Genres:  ['candy pop', 'scottish singer-songwriter']
# Genres:  ['healing', 'new age', 'synthesizer']
# Genres:  ['big band', 'swing']
# Genres:  ['gospel']
# Genres:  []
# Genres:  ['ghettotech']
# Genres:  ['glam metal', 'hard rock']
# Genres:  ['german alternative rap', 'german pop', 'hamburg hip hop', 'oldschool deutschrap']
# Genres:  ['anti-folk', 'indietronica', 'lo-fi']
# Genres:  []
# Batch completed at 09:58:46
# Processed 14 tracks in this batch
# Total tracks processed: 8020
# Last track processed: 124 stomp
# Last track genres: No genres found
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 322 of 402
# Processing rows 8031 to 8056
# Genres:  ['alternative rock', 'anti-folk', 'chamber pop', 'countrygaze', 'lo-fi', 'melancholia', 'noise pop', 'outsider']
# Genres:  ['new jersey rap']
# Genres:  ['nz electronic', 'nz reggae', 'psychill']
# Genres:  ['norteno', 'tejano']
# Genres:  ['classic dubstep']
# Genres:  ['glam metal', 'speed metal', 'us power metal']
# Genres:  []
# Genres:  ['australian alternative rock', 'protopunk']
# Genres:  ['afropop', 'rumba congolaise', 'soukous', 'zilizopendwa']
# Genres:  ['country', 'country rock', 'outlaw country']
# Genres:  ['blues', 'blues rock', 'british blues', 'electric blues', 'harmonica blues', 'traditional blues']
# Genres:  ['west virginia indie']
# Genres:  ['brazilian rock', 'mpb', 'musica maranhense']
# Genres:  ['mexican rock-and-roll', 'ranchera']
# Genres:  ['ccm', 'christian alternative rock', 'christian music']
# Batch completed at 09:59:35
# Processed 15 tracks in this batch
# Total tracks processed: 8046
# Last track processed: les dxc3xa9penaillxc3xa9s
# Last track genres: ['ccm', 'christian alternative rock', 'christian music']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 323 of 402
# Processing rows 8056 to 8081
# Genres:  ['blues', 'blues rock', 'british blues', 'british invasion', 'electric blues', 'traditional blues']
# Genres:  ['bronx hip hop', 'old school hip hop']
# Genres:  ['german rock', 'neue deutsche welle']
# Genres:  ['dancehall', 'lovers rock', 'reggae', 'roots reggae']
# Genres:  []
# Genres:  ['dance-punk', 'experimental rock', 'grave wave', 'noise rock']
# Genres:  []
# Genres:  ['canadian blues']
# Genres:  ['detroit hip hop']
# Genres:  ['adult standards', 'easy listening', 'lounge', 'rock-and-roll', 'rockabilly', 'vocal jazz']
# Genres:  ['salsa', 'salsa colombiana']
# Genres:  ['chicago soul', 'classic soul', 'motown']
# Genres:  ['hammond organ']
# Genres:  ['black metal', 'norwegian black metal', 'norwegian metal', 'symphonic black metal']
# Genres:  []
# Genres:  ['alternative country', 'ectofolk', 'folk', 'lilith', 'singer-songwriter', "women's music"]
# Genres:  ['classic house', 'vocal house']
# Genres:  ['canadian blues']
# Genres:  ['blues', 'boogie-woogie', 'louisiana blues', 'memphis blues', 'new orleans blues', 'new orleans soul', 'piano blues', 'traditional blues']
# Genres:  ['glam rock']
# Genres:  ['country gospel']
# Batch completed at 10:00:25
# Processed 21 tracks in this batch
# Total tracks processed: 8077
# Last track processed: it came upon a midnight clear
# Last track genres: ['country gospel']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 324 of 402
# Processing rows 8081 to 8106
# Genres:  ['pop flamenco', 'rumba', 'spanish pop']
# Genres:  ['classic texas country', 'outlaw country']
# Genres:  ['alternative metal', 'california hardcore', 'crossover thrash', 'funk metal', 'hard rock', 'hardcore punk', 'metal', 'nu metal', 'old school thrash', 'punk', 'thrash metal']
# Genres:  ['country blues', 'memphis blues', 'traditional blues']
# Genres:  ['country blues', 'delta blues', 'traditional blues']
# Genres:  []
# Genres:  []
# Genres:  ['alternative rock', 'modern power pop', 'modern rock', 'permanent wave', 'rock']
# Genres:  ['eurodance', 'hip house']
# Genres:  ['c-pop', 'cantopop', 'classic cantopop']
# Genres:  ['musica costena']
# Genres:  []
# Genres:  ['heartland rock']
# Genres:  ['british soul', 'sophisti-pop']
# Batch completed at 10:01:13
# Processed 14 tracks in this batch
# Total tracks processed: 8095
# Last track processed: morning bird
# Last track genres: ['british soul', 'sophisti-pop']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 325 of 402
# Processing rows 8106 to 8131
# Genres:  ['album rock', 'classic rock', 'hard rock', 'rock']
# Genres:  ['norwegian gospel']
# Genres:  ['galician folk']
# Genres:  ['smooth jazz', 'smooth saxophone']
# Genres:  ['country blues', 'memphis blues', 'traditional blues']
# Genres:  ['piedmont blues', 'traditional blues']
# Genres:  ['dutch pop', 'dutch rock']
# Genres:  ['alternative metal', 'boston metal', 'industrial metal', 'melodic metalcore', 'melodic thrash', 'metalcore', 'new england metal', 'nu metal']
# Genres:  []
# Genres:  ['canadian blues', 'classic canadian rock']
# Batch completed at 10:02:01
# Processed 10 tracks in this batch
# Total tracks processed: 8116
# Last track processed: ni shi wo xin zhong yi ju jing tan
# Last track genres: ['canadian blues', 'classic canadian rock']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 326 of 402
# Processing rows 8131 to 8156
# Genres:  []
# Genres:  ['ghettotech']
# Genres:  ['alternative metal', 'alternative rock', 'grunge', 'post-hardcore', 'punk', 'sludge metal', 'stoner metal']
# Genres:  []
# Genres:  ['lds youth']
# Genres:  ['atmospheric black metal', 'avant-garde metal', 'balkan folk metal', 'black metal', 'blackgaze', 'pagan black metal', 'romanian black metal', 'romanian metal', 'slavic metal']
# Genres:  ['chicago soul', 'doo-wop', 'rhythm and blues']
# Genres:  ['nz electronic', 'nz reggae', 'psychill']
# Genres:  ['christian hardcore', 'christian punk']
# Genres:  ['east coast hip hop', 'hardcore hip hop', 'hip hop', 'pop rap', 'rap']
# Genres:  ['lullaby']
# Genres:  ['british experimental', 'hauntology', 'uk experimental electronic']
# Genres:  ['alternative rock', 'grunge', 'punk']
# Genres:  ['greek pop', 'laiko']
# Genres:  ['video game music']
# Batch completed at 10:02:50
# Processed 15 tracks in this batch
# Total tracks processed: 8146
# Last track processed: misty bog
# Last track genres: ['video game music']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 327 of 402
# Processing rows 8156 to 8181
# Genres:  []
# Genres:  ['latin arena pop', 'latin pop', 'spanish pop', 'spanish pop rock']
# Genres:  ['dub', 'lovers rock', 'reggae', 'rocksteady', 'roots reggae']
# Genres:  []
# Genres:  ['blues', 'blues rock', 'canadian blues', 'country rock', 'electric blues', 'modern blues']
# Genres:  ['idol']
# Genres:  ['atmospheric post-metal', 'atmospheric sludge', 'djent', 'post-metal', 'progressive metal', 'progressive sludge', 'sludge metal']
# Genres:  ['abstract hip hop']
# Genres:  ['deep house']
# Genres:  []
# Genres:  ['classic finnish rock', 'suomi rock']
# Genres:  []
# Genres:  ['argentine rock', 'ska argentino']
# Genres:  []
# Genres:  ['australian alternative rock', 'perth indie']
# Genres:  ['mambo', 'salsa', 'salsa colombiana']
# Genres:  ['nashville sound']
# Genres:  ['bal-musette', 'jazz accordion']
# Batch completed at 10:03:39
# Processed 18 tracks in this batch
# Total tracks processed: 8174
# Last track processed: gracieusette
# Last track genres: ['bal-musette', 'jazz accordion']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 328 of 402
# Processing rows 8181 to 8206
# Genres:  ['21st century classical', 'american contemporary classical', 'avant-garde', 'compositional ambient', 'contemporary classical', 'experimental', 'fourth world', 'minimalism', 'tzadik']
# Genres:  ['sasscore', 'synth punk']
# Genres:  ['french folk pop', 'french reggae', 'french rock']
# Genres:  ['canadian classical piano']
# Genres:  []
# Genres:  ['instrumental bluegrass', 'progressive bluegrass']
# Genres:  ['album rock', 'blues', 'blues rock', 'classic rock', 'electric blues', 'hard rock', 'instrumental rock', 'rock', 'texas blues']
# Genres:  ['cape town indie', 'downtempo', 'south african pop', 'south african pop dance']
# Genres:  ['alternative metal', 'canadian rock', 'post-grunge']
# Genres:  ['dancehall', 'jamaican dancehall']
# Genres:  ['jazz double bass']
# Genres:  ['nashville sound']
# Genres:  ['deep eurodance', 'hip house']
# Genres:  ['alternative rock']
# Genres:  ['hardcore punk', 'oi', 'punk', 'uk82']
# Genres:  ['adult standards', 'contemporary vocal jazz', 'lounge', 'vocal jazz']
# Genres:  ['album rock', 'blues rock', 'classic rock', 'electric blues', 'hard rock', 'jam band', 'rock', 'southern rock']
# Batch completed at 10:04:28
# Processed 17 tracks in this batch
# Total tracks processed: 8198
# Last track processed: secret lovers featuring mica paris
# Last track genres: ['album rock', 'blues rock', 'classic rock', 'electric blues', 'hard rock', 'jam band', 'rock', 'southern rock']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 329 of 402
# Processing rows 8206 to 8231
# Genres:  ['new romantic', 'new wave', 'new wave pop']
# Genres:  ['album rock', 'blues rock', 'british blues', 'classic rock', 'hard rock']
# Genres:  []
# Genres:  ['belgian rock', 'dance-punk']
# Genres:  ['beatlesque']
# Genres:  ['bolero', 'cancion melodica', 'latin pop', 'ranchera']
# Genres:  ['new romantic', 'new wave', 'new wave pop', 'singer-songwriter', 'soft rock', 'synthpop']
# Genres:  ['zilizopendwa']
# Genres:  ['album rock', 'classic rock', 'hard rock', 'rock']
# Genres:  ['canadian soundtrack', 'soundtrack']
# Genres:  ['black metal', 'finnish black metal', 'lapland metal', 'war metal']
# Genres:  ['alternative rock', 'baroque pop', 'beatlesque', 'jangle pop', 'melancholia', 'power pop']
# Genres:  ['accordion', 'french folk']
# Genres:  ['healing', 'new age', 'synthesizer']
# Genres:  []
# Genres:  ['dance pop', 'pop', 'urban contemporary']
# Genres:  ['chicago soul', 'classic soul', 'funk', 'quiet storm', 'soul']
# Genres:  ['punk', 'skate punk']
# Batch completed at 10:05:17
# Processed 18 tracks in this batch
# Total tracks processed: 8224
# Last track processed: ask the angels
# Last track genres: ['punk', 'skate punk']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 330 of 402
# Processing rows 8231 to 8256
# Genres:  []
# Genres:  ['g funk', 'west coast rap']
# Genres:  ['experimental rock', 'japanoise', 'math rock', 'noise rock', 'noisecore']
# Genres:  ['rap kreyol']
# Genres:  ['ectofolk', 'lilith']
# Genres:  ['horror punk', 'new jersey hardcore', 'new jersey punk', 'punk']
# Genres:  ['country blues', 'texas blues', 'traditional blues']
# Genres:  ['british blues', 'british invasion', 'protopunk']
# Genres:  ['colombian pop', 'dance pop', 'latin pop', 'pop']
# Genres:  ['doom metal', 'finnish death metal', 'finnish doom metal', 'finnish melodeath', 'finnish metal', 'melodic death metal']
# Genres:  ['melancholia']
# Genres:  ['modern progressive rock', 'norwegian prog']
# Genres:  ['french soundtrack', 'orchestral soundtrack', 'soundtrack']
# Genres:  ['blues rock', 'british blues', 'electric blues']
# Genres:  []
# Genres:  ['ccm', 'christian alternative rock', 'christian music']
# Batch completed at 10:06:06
# Processed 16 tracks in this batch
# Total tracks processed: 8247
# Last track processed: hard to concentrate album version
# Last track genres: ['ccm', 'christian alternative rock', 'christian music']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 331 of 402
# Processing rows 8256 to 8281
# Genres:  ['dutch pop']
# Genres:  ['diva house', 'eurodance', 'europop', 'hip house']
# Genres:  ['vbs']
# Genres:  ['pop']
# Genres:  ['breakcore', 'digital hardcore']
# Genres:  ['folk metal', 'nordic folk metal', 'viking metal']
# Genres:  ['canadian modern jazz']
# Genres:  ['neon pop punk']
# Genres:  []
# Genres:  ['vintage hollywood']
# Genres:  ['bal-musette', 'jazz accordion']
# Genres:  ['irish folk', 'uilleann pipes']
# Genres:  ['latvian pop']
# Genres:  ['arkansas country', 'classic country pop', 'country', 'country rock']
# Genres:  ['bal-musette', 'jazz accordion']
# Genres:  ['greek pop', 'laiko']
# Genres:  ['boston rock', 'protopunk', 'rhythm rock']
# Genres:  ['classic finnish pop', 'classic iskelma', 'iskelma']
# Genres:  ['neo-synthpop']
# Batch completed at 10:06:55
# Processed 19 tracks in this batch
# Total tracks processed: 8275
# Last track processed: remote control
# Last track genres: ['neo-synthpop']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 332 of 402
# Processing rows 8281 to 8306
# Genres:  ['australian dance', 'classic hardstyle', 'euphoric hardstyle', 'gabber', 'happy hardcore']
# Genres:  ['jangle pop']
# Genres:  ['contemporary r&b', 'minneapolis sound', 'new jack swing', 'r&b']
# Genres:  ['indie jazz', 'modern chamber music']
# Genres:  []
# Genres:  ['norwegian doom metal', 'norwegian metal', 'norwegian rock']
# Genres:  []
# Genres:  ['norwegian experimental']
# Genres:  ['mariachi', 'ranchera']
# Genres:  ['contemporary vocal jazz']
# Batch completed at 10:07:43
# Processed 10 tracks in this batch
# Total tracks processed: 8291
# Last track processed: game night album version
# Last track genres: ['contemporary vocal jazz']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 333 of 402
# Processing rows 8306 to 8331
# Genres:  ['southern gospel']
# Genres:  ['british dance band', "man's orchestra"]
# Genres:  ['cha-cha-cha', 'charanga', 'mambo', 'musica tradicional cubana', 'son cubano clasico']
# Genres:  ['alternative metal', 'nu metal', 'pop punk', 'post-grunge', 'punk', 'screamo']
# Genres:  ['french folk pop', 'french reggae', 'french rock']
# Genres:  []
# Genres:  ['classic country pop', 'country', 'country road', 'country rock']
# Genres:  ['austrian black metal', 'austrian metal', 'black metal', 'brutal death metal', 'death metal', 'symphonic black metal']
# Genres:  ['adult standards', 'brill building pop', 'disco', 'quiet storm', 'soft rock', 'soul', 'vocal jazz']
# Genres:  ['alternative rock', 'garage rock', 'garage rock revival', 'modern blues rock', 'palm desert scene']
# Genres:  ['soundtrack']
# Genres:  ['musica costena']
# Genres:  ['skate punk']
# Genres:  []
# Genres:  []
# Genres:  ['argentine rock', 'post-punk argentina', 'rock nacional']
# Genres:  ['world fusion']
# Batch completed at 10:08:32
# Processed 17 tracks in this batch
# Total tracks processed: 8323
# Last track processed: eeshwar
# Last track genres: ['world fusion']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 334 of 402
# Processing rows 8331 to 8356
# Genres:  ['soft rock', 'sophisti-pop']
# Genres:  ['gospel']
# Genres:  ['abstract hip hop']
# Genres:  ['dirty south rap', 'st louis rap']
# Genres:  []
# Genres:  ['folk rock']
# Genres:  ['emo', 'modern rock', 'pop punk', 'pov: indie', 'rock']
# Genres:  ['acoustic blues', 'blues', 'country blues', 'delta blues', 'traditional blues']
# Genres:  ['family gospel', 'southern gospel']
# Genres:  ['classic country pop']
# Genres:  ['alternative rock', 'glam rock', 'permanent wave', 'protopunk', 'rock']
# Genres:  ['ghettotech']
# Genres:  ['dance pop', 'pop']
# Genres:  ['mandopop', 'singaporean mandopop', 'singaporean pop', 'singaporean singer-songwriter', 'taiwan singer-songwriter']
# Genres:  ['family gospel']
# Genres:  ['alternative rock', 'art rock', 'melancholia', 'oxford indie', 'permanent wave', 'rock']
# Genres:  []
# Genres:  ['cancion melodica']
# Batch completed at 10:09:21
# Processed 18 tracks in this batch
# Total tracks processed: 8349
# Last track processed: night terrors album version
# Last track genres: ['cancion melodica']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 335 of 402
# Processing rows 8356 to 8381
# Genres:  ['jesus movement']
# Genres:  ['deep christian rock']
# Genres:  ['spanish pop rock']
# Genres:  ['christian music', 'deep christian rock']
# Genres:  ['bolero cubano', 'cha-cha-cha', 'charanga', 'danzon', 'latin jazz', 'mambo', 'musica tradicional cubana', 'salsa', 'son cubano clasico']
# Genres:  ['chicago blues', 'piano blues']
# Genres:  ['new romantic', 'new wave pop', 'sophisti-pop', 'synthpop']
# Genres:  ['norteno', 'tejano']
# Genres:  ['indietronica', 'pop']
# Genres:  ['acoustic blues', 'louisiana blues', 'swamp blues', 'swamp pop', 'swamp rock']
# Genres:  []
# Genres:  []
# Genres:  ['modern ska punk', 'pop punk', 'punk', 'ska', 'ska punk', 'skate punk']
# Genres:  ['classic country pop', 'country', 'country rock']
# Genres:  ['canadian classical piano']
# Batch completed at 10:10:10
# Processed 15 tracks in this batch
# Total tracks processed: 8371
# Last track processed: nocturne for piano no 5 in b flat major_ op 37
# Last track genres: ['canadian classical piano']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 336 of 402
# Processing rows 8381 to 8406
# Genres:  ['deep ragga', 'lovers rock']
# Genres:  ['experimental psych', 'free folk', 'raga rock']
# Genres:  ['classical', 'classical era']
# Genres:  ['rock drums']
# Genres:  ['east coast hip hop', 'hardcore hip hop', 'hip hop', 'pop rap', 'rap']
# Genres:  []
# Genres:  ['bossa nova', 'pagode', 'partido alto', 'samba', 'umbanda', 'velha guarda']
# Genres:  ['alternative rock', 'melancholia', 'permanent wave', 'protopunk', 'rock']
# Genres:  []
# Genres:  ['adult standards', 'mellow gold', 'soft rock', 'yacht rock']
# Genres:  ['conscious hip hop', 'industrial hip hop']
# Genres:  ['dance rock', 'new romantic', 'new wave', 'new wave pop']
# Genres:  []
# Genres:  []
# Genres:  ['ectofolk', 'lilith', 'neo mellow', 'pop rock', 'scottish singer-songwriter']
# Genres:  ['blackened deathcore', 'deathcore', 'melodic metalcore', 'metalcore', 'symphonic deathcore']
# Genres:  ['post-hardcore', 'screamo', 'uk post-hardcore']
# Genres:  []
# Genres:  ['album rock', 'glam rock', 'hard rock']
# Batch completed at 10:10:59
# Processed 19 tracks in this batch
# Total tracks processed: 8400
# Last track processed: neon psychedelia
# Last track genres: ['album rock', 'glam rock', 'hard rock']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 337 of 402
# Processing rows 8406 to 8431
# Genres:  ['ambient dub', 'dub techno', 'german techno', 'intelligent dance music', 'microhouse', 'minimal techno', 'techno']
# Genres:  ['emo', 'pop punk', 'pop rock', 'skate punk']
# Genres:  ['fantasy metal', 'finnish metal', 'finnish power metal', 'gothic metal', 'gothic symphonic metal', 'opera metal', 'power metal', 'symphonic metal']
# Genres:  []
# Genres:  ['blues', 'blues rock', 'classic rock', 'electric blues', 'jazz blues', 'soul', 'soul blues', 'traditional blues']
# Genres:  ['new jersey hardcore']
# Genres:  ['album rock', 'blues rock', 'classic rock', 'electric blues', 'hard rock', 'jam band', 'rock', 'southern rock']
# Genres:  ['argentine rock', 'latin alternative', 'latin pop', 'latin rock', 'rock en espanol', 'ska', 'ska argentino']
# Genres:  ['orchestral soundtrack', 'scorecore', 'soundtrack']
# Genres:  ['british invasion']
# Genres:  ['acoustic blues', 'blues', 'country blues', 'delta blues', 'piedmont blues', 'traditional blues']
# Genres:  ['album rock', 'classic rock', 'hard rock', 'rock']
# Genres:  ['chanson', 'french pop', 'french rock', 'nouvelle chanson francaise']
# Genres:  ['adult standards', 'brill building pop', 'folk rock', 'mellow gold', 'singer-songwriter', 'soft rock', 'yacht rock']
# Genres:  ['latin arena pop', 'latin pop', 'mexican pop']
# Genres:  []
# Batch completed at 10:11:48
# Processed 16 tracks in this batch
# Total tracks processed: 8422
# Last track processed: mua rakastan
# Last track genres: No genres found
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 338 of 402
# Processing rows 8431 to 8456
# Genres:  ['dub', 'reggae', 'roots reggae', 'uk dub']
# Genres:  ['chicago blues']
# Genres:  []
# Genres:  ['cantopop']
# Genres:  []
# Genres:  []
# Genres:  ['dancehall', 'lovers rock', 'old school dancehall', 'reggae', 'roots reggae']
# Genres:  ['lovers rock', 'reggae', 'roots reggae']
# Genres:  ['art rock', 'glam rock']
# Genres:  ['rumba', 'rumba catalana']
# Genres:  ['american folk revival', 'folk']
# Genres:  []
# Genres:  []
# Genres:  ['smooth jazz', 'smooth saxophone']
# Genres:  ['dance-punk']
# Genres:  []
# Genres:  ['glam metal']
# Genres:  []
# Genres:  ['new age']
# Genres:  ['abstract hip hop', 'alternative hip hop']
# Genres:  ['country blues', 'memphis blues', 'traditional blues']
# Genres:  ['dancehall', 'dancehall queen', 'reggae fusion']
# Batch completed at 10:12:38
# Processed 22 tracks in this batch
# Total tracks processed: 8453
# Last track processed: to sir with love
# Last track genres: ['dancehall', 'dancehall queen', 'reggae fusion']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 339 of 402
# Processing rows 8456 to 8481
# Genres:  ['prepared piano']
# Genres:  ['orchestral soundtrack', 'soundtrack']
# Genres:  ['country dawn']
# Genres:  []
# Genres:  ['bluegrass', 'jam band', 'progressive bluegrass']
# Genres:  ['mariachi', 'ranchera']
# Genres:  ['dance-punk', 'experimental rock', 'grave wave', 'noise rock']
# Genres:  ['country boogie', 'western swing']
# Genres:  ['classic praise', 'deep christian rock']
# Genres:  ['family gospel', 'southern gospel']
# Genres:  ['british blues', 'progressive rock', 'proto-metal']
# Genres:  ['cancion melodica', 'copla', 'pop romantico']
# Genres:  ['new age']
# Genres:  ['blues', 'memphis blues', 'texas blues', 'traditional blues']
# Genres:  ['dancehall', 'dancehall queen', 'reggae fusion']
# Genres:  ['aggrotech', 'industrial metal', 'steampunk']
# Batch completed at 10:13:26
# Processed 16 tracks in this batch
# Total tracks processed: 8472
# Last track processed: we are the ones lounge version
# Last track genres: ['aggrotech', 'industrial metal', 'steampunk']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 340 of 402
# Processing rows 8481 to 8506
# Genres:  ['lds youth']
# Genres:  ['electro house', 'progressive electro house']
# Genres:  ['album rock', 'blues rock', 'classic rock', 'country rock', 'folk rock', 'heartland rock', 'mellow gold', 'singer-songwriter', 'soft rock', 'southern rock', 'swamp rock']
# Genres:  []
# Genres:  []
# Genres:  ['cowboy western', 'western swing']
# Genres:  []
# Genres:  ['southern gospel']
# Genres:  []
# Genres:  ['psychill', 'world fusion']
# Genres:  ['blues', 'harlem renaissance', 'jazz blues', 'traditional blues']
# Genres:  ['neue deutsche welle']
# Genres:  ['british folk', 'celtic', 'irish folk', 'uilleann pipes']
# Genres:  ['blues rock', 'proto-metal', 'psychedelic rock']
# Genres:  ['gospel']
# Batch completed at 10:14:15
# Processed 15 tracks in this batch
# Total tracks processed: 8496
# Last track processed: psalm 27
# Last track genres: ['gospel']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 341 of 402
# Processing rows 8506 to 8531
# Genres:  ['dance rock', 'new romantic', 'new wave', 'new wave pop']
# Genres:  ['album rock', 'british invasion', 'classic rock', 'rock']
# Genres:  ['acoustic blues', 'blues', 'country blues', 'delta blues', 'gospel blues', 'pre-war blues', 'texas blues', 'traditional blues']
# Genres:  ['clean comedy', 'country gospel']
# Genres:  ['lilith', 'new wave pop', 'permanent wave', 'pop rock', 'swedish pop']
# Genres:  ['grupera', 'mexican rock-and-roll', 'norteno', 'ranchera']
# Genres:  ['classic country pop', 'country', 'nashville sound', 'soft rock']
# Genres:  ['new age']
# Genres:  ['classic garage rock', 'garage rock', 'protopunk']
# Genres:  ['acoustic blues', 'traditional blues']
# Genres:  []
# Genres:  ['blues rock', 'british blues', 'classic rock', 'progressive rock', 'psychedelic rock']
# Genres:  ['flick hop', 'underground rap']
# Genres:  ['latin pop', 'pop flamenco', 'rumba', 'spanish pop']
# Genres:  ['alternative rock', 'experimental rock', 'grunge', 'noise rock', 'psychedelic punk', 'punk']
# Batch completed at 10:15:04
# Processed 15 tracks in this batch
# Total tracks processed: 8521
# Last track processed: 22 going on 23
# Last track genres: ['alternative rock', 'experimental rock', 'grunge', 'noise rock', 'psychedelic punk', 'punk']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 342 of 402
# Processing rows 8531 to 8556
# Genres:  ['contemporary r&b', 'new jack swing', 'r&b', 'reggae fusion']
# Genres:  ['ghettotech']
# Genres:  ['hip pop', 'r&b', 'urban contemporary']
# Genres:  []
# Genres:  ['world fusion']
# Genres:  []
# Genres:  ['family gospel']
# Genres:  ['conscious hip hop', 'crunk', 'dirty south rap', 'mississippi hip hop', 'southern hip hop']
# Genres:  ['classic country pop', 'traditional country']
# Genres:  ['acousmatic', 'belgian contemporary classical', 'belgian experimental', 'musique concrete', 'serialism']
# Genres:  ['alternative metal', 'nu metal', 'post-grunge', 'uk metalcore', 'welsh metal']
# Genres:  []
# Genres:  ['afropop', 'desert blues', 'malian blues', 'moroccan rock', 'musique touareg', 'tuareg guitar', 'western saharan folk', 'world']
# Genres:  []
# Genres:  ['alternative hip hop', 'modern rock', 'rock']
# Batch completed at 10:15:53
# Processed 15 tracks in this batch
# Total tracks processed: 8546
# Last track processed: all alone live
# Last track genres: ['alternative hip hop', 'modern rock', 'rock']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 343 of 402
# Processing rows 8556 to 8581
# Genres:  ['latin pop', 'spanish pop']
# Genres:  ['british dance band', "man's orchestra"]
# Genres:  []
# Genres:  ['rock drums', 'soft rock']
# Genres:  ['gospel', 'gospel r&b', 'jesus movement']
# Genres:  ['punk', 'skate punk']
# Genres:  ['indie catala', 'musica catalana', 'rock catala', 'rumba', 'rumba catalana']
# Genres:  ['puerto rican pop']
# Genres:  ['big room', 'dance pop', 'edm', 'pop', 'pop dance']
# Genres:  ['moog', 'vintage french electronic', 'zolo']
# Genres:  []
# Genres:  ['arkansas country', 'classic country pop', 'country gospel']
# Genres:  []
# Genres:  ['classic french pop']
# Genres:  ['ranchera']
# Genres:  ['bulgarian pop', 'classic bulgarian pop']
# Batch completed at 10:16:42
# Processed 16 tracks in this batch
# Total tracks processed: 8572
# Last track processed: pokrusa
# Last track genres: ['bulgarian pop', 'classic bulgarian pop']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 344 of 402
# Processing rows 8581 to 8606
# Genres:  ['crunk', 'electropowerpop']
# Genres:  ['alternative metal', 'alternative rock', 'australian alternative rock', 'australian psych', 'australian rock', 'grunge', 'nu metal', 'post-grunge']
# Genres:  ['irish ballad']
# Genres:  ['classical', 'classical era']
# Genres:  ['alternative rock', 'detroit rock', 'permanent wave', 'protopunk', 'punk']
# Genres:  ['east coast hip hop', 'golden age hip hop', 'hip hop', 'old school hip hop']
# Genres:  ['east coast hip hop', 'harlem hip hop', 'old school hip hop']
# Genres:  ['doo-wop', 'sunshine pop']
# Genres:  ['orchestral soundtrack', 'soundtrack']
# Genres:  ['jump blues', 'piano blues', 'rhythm and blues', 'soul blues', 'southern soul']
# Genres:  ['stomp pop']
# Batch completed at 10:17:30
# Processed 11 tracks in this batch
# Total tracks processed: 8592
# Last track processed: red gun
# Last track genres: ['stomp pop']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 345 of 402
# Processing rows 8606 to 8631
# Genres:  ['lilith', 'new wave pop']
# Genres:  ['black metal', 'death metal', 'groove metal', 'metal', 'pagan black metal', 'polish black metal', 'polish death metal', 'polish metal']
# Genres:  ['alternative rock', 'pop rock', 'post-grunge', 'sacramento indie']
# Genres:  ['chicago rap', 'gangster rap', 'memphis hip hop']
# Genres:  ['c-pop', 'cantopop']
# Genres:  ['space ambient']
# Genres:  ['permanent wave', 'pop']
# Genres:  ['tropical']
# Genres:  ['alternative rock', 'art punk', 'dance rock', 'funk rock', 'post-punk', 'punk', 'uk post-punk']
# Genres:  ['contemporary r&b', 'quiet storm', 'urban contemporary']
# Genres:  ['chicago soul', 'classic soul', 'rhythm and blues', 'soul']
# Genres:  ['boston punk', 'boston rock', 'punk', 'ska', 'ska punk', 'skate punk']
# Genres:  ['contemporary country', 'country', 'country road']
# Genres:  ['latvian pop']
# Genres:  ['deep comedy']
# Batch completed at 10:18:19
# Processed 15 tracks in this batch
# Total tracks processed: 8621
# Last track processed: inti guauqui
# Last track genres: ['deep comedy']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 346 of 402
# Processing rows 8631 to 8656
# Genres:  ['classic country pop', 'country', 'country rock', 'honky tonk']
# Genres:  ['classic finnish rock', 'classic iskelma', 'suomi rock']
# Genres:  ['celtic', 'irish folk']
# Genres:  ['piedmont blues']
# Genres:  ['ectofolk', 'lilith']
# Genres:  []
# Genres:  ['funk rock', 'jam band', 'new orleans funk']
# Genres:  ['album rock', 'classic rock', 'dance rock', 'mellow gold', 'new romantic', 'new wave', 'new wave pop', 'singer-songwriter', 'soft rock', 'yacht rock']
# Genres:  ['contemporary jazz', 'contemporary post-bop', 'jazz cubano', 'jazz piano', 'modern jazz piano']
# Genres:  []
# Genres:  ['album rock', 'glam metal', 'hard rock']
# Genres:  ['alternative rock', 'britpop', 'permanent wave', 'rock']
# Genres:  ['cajun', 'country boogie']
# Genres:  []
# Genres:  []
# Batch completed at 10:19:07
# Processed 15 tracks in this batch
# Total tracks processed: 8646
# Last track processed: fly talkin
# Last track genres: No genres found
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 347 of 402
# Processing rows 8656 to 8681
# Genres:  []
# Genres:  []
# Genres:  ['grunge pop']
# Genres:  ['punk', 'skate punk', 'socal pop punk']
# Genres:  []
# Genres:  ['german pop', 'german rock', 'oldschool deutschrap']
# Genres:  ['hardcore punk', 'new jersey punk', 'oi', 'street punk']
# Genres:  ['cardiff indie']
# Genres:  ['dancehall', 'jamaican dancehall', 'reggae fusion', 'soca']
# Genres:  ['ghettotech']
# Genres:  ['vintage chanson', 'ye ye']
# Genres:  ['chanson']
# Genres:  ['jesus movement']
# Genres:  ['contemporary r&b', 'new jack swing', 'r&b', 'reggae fusion']
# Genres:  []
# Genres:  ['alternative country', 'country rock', 'folk', 'heartland rock', 'roots rock']
# Genres:  ['beatdown', 'hardcore', 'straight edge']
# Genres:  ['alternative rock', 'britpop', 'madchester', 'new wave', 'post-punk', 'punk', 'uk post-punk']
# Genres:  ['acoustic blues', 'blues', 'country blues', 'delta blues', 'gospel blues', 'pre-war blues', 'texas blues', 'traditional blues']
# Genres:  ['tango']
# Genres:  ['c-pop', 'classic mandopop', 'mandopop']
# Genres:  ['country', 'country road']
# Batch completed at 10:19:57
# Processed 22 tracks in this batch
# Total tracks processed: 8678
# Last track processed: unsafe sextetgilded hearts of booklovers
# Last track genres: ['country', 'country road']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 348 of 402
# Processing rows 8681 to 8706
# Genres:  ['blues', 'blues rock', 'chicago blues', 'electric blues', 'traditional blues']
# Genres:  ['banda', 'musica mexicana', 'norteno']
# Genres:  ['glam metal']
# Genres:  ['gaita', 'musica folk asturiana']
# Genres:  ['country blues', 'memphis blues', 'traditional blues']
# Genres:  ['alternative metal', 'nu metal', 'rap metal', 'rock']
# Genres:  ['avant-garde', 'classical', 'contemporary classical', 'early modern classical', 'laboratorio']
# Genres:  ['power blues-rock']
# Genres:  ['dancehall', 'lovers rock', 'old school dancehall', 'reggae', 'roots reggae']
# Genres:  ['spacegrunge']
# Genres:  ['celtic', 'irish folk']
# Genres:  []
# Batch completed at 10:20:45
# Processed 12 tracks in this batch
# Total tracks processed: 8693
# Last track processed: good friend
# Last track genres: No genres found
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 349 of 402
# Processing rows 8706 to 8731
# Genres:  ['britpop', 'dance rock', 'grebo']
# Genres:  ['alternative rock', 'funk metal', 'funk rock', 'permanent wave', 'rock']
# Genres:  []
# Genres:  ['lovers rock', 'old school dancehall', 'reggae', 'roots reggae']
# Genres:  ['chicago soul', 'classic soul']
# Genres:  ['glam metal', 'hard rock']
# Genres:  ['album rock', 'classic rock', 'permanent wave', 'rock']
# Genres:  []
# Genres:  ['cantopop']
# Genres:  ['east coast hip hop']
# Genres:  []
# Genres:  ['art pop']
# Genres:  ['hoerspiel']
# Genres:  ['detroit hip hop', 'east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'rap']
# Genres:  ['brill building pop', 'classic girl group', 'motown', 'rock-and-roll']
# Genres:  ['american metalcore', 'mathcore', 'new jersey hardcore', 'new jersey punk', 'post-hardcore']
# Batch completed at 10:21:34
# Processed 16 tracks in this batch
# Total tracks processed: 8722
# Last track processed: lets start all over
# Last track genres: ['american metalcore', 'mathcore', 'new jersey hardcore', 'new jersey punk', 'post-hardcore']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 350 of 402
# Processing rows 8731 to 8756
# Genres:  ['chanson', 'french pop', 'french rock', 'nouvelle chanson francaise']
# Genres:  []
# Genres:  ['acoustic blues', 'appalachian folk', 'jug band', 'memphis blues', 'traditional blues', 'traditional folk']
# Genres:  ['ghettotech']
# Genres:  ['alternative country']
# Genres:  ['bluegrass', 'jam band', 'progressive bluegrass']
# Genres:  ['battle rap', 'hardcore hip hop', 'hip pop', 'philly rap', 'southern hip hop', 'trap']
# Genres:  ['chanson', 'ye ye']
# Genres:  ['acoustic blues', 'blues']
# Genres:  ['glam metal', 'hard rock', 'melodic hard rock', 'neo classical metal']
# Genres:  ['oi', 'punk']
# Genres:  ['bossa nova jazz', 'brazilian jazz', 'jazz funk']
# Genres:  ['diva house', 'garage house', 'vocal house']
# Genres:  ['classic country pop', 'country', 'country rock', 'honky tonk']
# Batch completed at 10:22:22
# Processed 14 tracks in this batch
# Total tracks processed: 8745
# Last track processed: these old eyes have seen it all
# Last track genres: ['classic country pop', 'country', 'country rock', 'honky tonk']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 351 of 402
# Processing rows 8756 to 8781
# Genres:  ['progressive metal', 'progressive rock']
# Genres:  []
# Genres:  []
# Genres:  ['blues', 'harlem renaissance', 'traditional blues']
# Genres:  []
# Genres:  ['ghettotech']
# Genres:  ['alternative metal', 'industrial metal', 'nu metal', 'rap metal', 'rap rock']
# Genres:  ['dancehall', 'jamaican dancehall', 'reggae fusion']
# Genres:  ['argentine rock', 'latin alternative', 'latin rock', 'rock en espanol']
# Genres:  ['bossa nova', 'brazilian jazz', 'jazz guitar', 'samba-jazz', 'violao']
# Genres:  ['classic country pop', 'nashville sound', 'traditional country', 'yodeling']
# Genres:  []
# Genres:  ['east coast hip hop', 'golden age hip hop', 'hip hop', 'old school hip hop']
# Batch completed at 10:23:11
# Processed 13 tracks in this batch
# Total tracks processed: 8769
# Last track processed: 4 minutes featuring justin timberlake and timbaland bob sinclar space funk remix
# Last track genres: ['east coast hip hop', 'golden age hip hop', 'hip hop', 'old school hip hop']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 352 of 402
# Processing rows 8781 to 8806
# Genres:  ['acoustic blues', 'blues', 'harmonica blues', 'louisiana blues', 'swamp blues', 'swamp rock', 'traditional blues']
# Genres:  ['brill building pop']
# ...
# Genres:  ['bakersfield sound', 'traditional country', 'western swing']
# Genres:  []
# Genres:  ['new italo disco']
# Genres:  []
# Genres:  []
# Genres:  []
# Genres:  ['contemporary r&b']
# Genres:  ['latin christian', 'latin worship']
# Genres:  []
# Genres:  ['entehno', 'greek pop', 'laiko']
# Genres:  ['country rock', 'southern rock']
# Genres:  ['accordion', 'bandoneon', 'classical accordion', 'french jazz', 'italian contemporary jazz', 'jazz accordion']
# Genres:  []
# Genres:  ['contemporary r&b', 'dance pop', 'r&b', 'urban contemporary']
# Batch completed at 10:54:54
# Processed 15 tracks in this batch
# Total tracks processed: 9746
# Last track processed: tell me
# Last track genres: ['contemporary r&b', 'dance pop', 'r&b', 'urban contemporary']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 391 of 402
# Processing rows 9756 to 9781
# Genres:  ['reggae fusion', 'reggae rock']
# Genres:  ['dub', 'old school dancehall', 'reggae', 'roots reggae']
# Genres:  ['baiao', 'bossa nova', 'velha guarda']
# Genres:  []
# Genres:  ['punk', 'skate punk', 'socal pop punk']
# Genres:  ['deathcore']
# Genres:  ['early us punk', 'glam punk', 'glam rock', 'protopunk', 'punk']
# Genres:  []
# Genres:  ['chicago blues']
# Genres:  ['cantopop', 'classic cantopop']
# Genres:  ['chanson', 'ye ye']
# Genres:  []
# Genres:  ['jamaican ska', 'rocksteady']
# Genres:  []
# Batch completed at 10:55:43
# Processed 14 tracks in this batch
# Total tracks processed: 9770
# Last track processed: leave me be
# Last track genres: No genres found
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 392 of 402
# Processing rows 9781 to 9806
# Genres:  ['east coast hip hop', 'harlem hip hop', 'new jack swing', 'old school hip hop']
# Genres:  ['dirty south rap', 'east coast hip hop']
# Genres:  ['west virginia indie']
# Genres:  ['eurodance', 'europop', 'italian adult pop', 'italo dance']
# Genres:  ['latin pop', 'ranchera']
# Genres:  []
# Genres:  ['anthem emo', 'easycore', 'pop punk']
# Genres:  []
# Genres:  []
# Genres:  ['jump blues', 'piano blues', 'rhythm and blues', 'soul blues', 'southern soul']
# Genres:  ['alternative dance', 'belgian electronic', 'belgian indie', 'belgian indie rock', 'belgian rock', 'electronica', 'filter house', 'ghent indie', 'mashup']
# Genres:  ['baroque', 'classical', 'early music', 'english baroque', 'german baroque']
# Genres:  ['bossa nova', 'mpb', 'samba', 'velha guarda']
# Genres:  ['oi']
# Genres:  []
# Genres:  ['big beat', 'breakbeat', 'electronica', 'intelligent dance music', 'rave']
# Genres:  []
# Genres:  ['dub', 'lovers rock', 'reggae', 'rocksteady', 'roots reggae']
# Genres:  ['british blues', 'classic uk pop']
# Batch completed at 10:56:32
# Processed 19 tracks in this batch
# Total tracks processed: 9800
# Last track processed: its a secret
# Last track genres: ['british blues', 'classic uk pop']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 393 of 402
# Processing rows 9806 to 9831
# Genres:  ['zouglou']
# Genres:  []
# Genres:  ['celtic', 'irish folk']
# Genres:  ['electro latino', 'funk mexicano', 'latin alternative', 'mexican rock', 'rock en espanol']
# Genres:  ['deathrock']
# Genres:  []
# Genres:  ['electronica', 'folktronica', 'indietronica', 'intelligent dance music', 'trip hop']
# Genres:  []
# Genres:  []
# Batch completed at 10:57:20
# Processed 9 tracks in this batch
# Total tracks processed: 9815
# Last track processed: better days album version
# Last track genres: No genres found
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 394 of 402
# Processing rows 9831 to 9856
# Genres:  ['dub', 'lovers rock', 'reggae', 'rocksteady', 'roots reggae']
# Genres:  ['early us punk', 'hardcore punk', 'punk']
# Genres:  ['adult standards', 'easy listening', 'lounge', 'rockabilly']
# Genres:  []
# Genres:  []
# Genres:  ['cowboy western', 'western swing']
# Genres:  ['black metal', 'death metal', 'groove metal', 'metal', 'pagan black metal', 'polish black metal', 'polish death metal', 'polish metal']
# Genres:  ['emo', 'modern rock', 'pop', 'rock']
# Genres:  ['nashville sound']
# Genres:  ['country dawn']
# Genres:  ['folk rock italiano', 'musica etnica', 'musica piemonteisa']
# Genres:  ['chill lounge', 'deep chill']
# Genres:  ['country gospel']
# Genres:  ['neo soul']
# Genres:  ['irish rock', 'permanent wave', 'rock']
# Genres:  ['emo', 'pop punk', 'pop rock', 'skate punk']
# Genres:  ['gothic rock', 'industrial', 'industrial rock', 'new wave', 'post-punk', 'uk post-punk']
# Batch completed at 10:58:09
# Processed 17 tracks in this batch
# Total tracks processed: 9848
# Last track processed: burning skies
# Last track genres: ['gothic rock', 'industrial', 'industrial rock', 'new wave', 'post-punk', 'uk post-punk']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 395 of 402
# Processing rows 9856 to 9881
# Genres:  ['country rock', 'folk', 'folk rock', 'singer-songwriter', 'yacht rock']
# Genres:  ['black comedy', 'deep comedy', 'latino comedy']
# Genres:  ['atl hip hop', 'conscious hip hop', 'hip hop', 'old school atlanta hip hop']
# Genres:  ['footwork']
# Genres:  ['c-pop', 'cantopop', 'classic cantopop']
# Genres:  []
# Genres:  ['canadian soundtrack', 'soundtrack']
# Genres:  ['british classical piano', 'historic piano performance']
# Genres:  ['acoustic blues', 'blues', 'country blues', 'gospel blues', 'texas blues', 'traditional blues']
# Genres:  ['black metal', 'celtic metal', 'doom metal', 'folk black metal', 'folk metal', 'irish black metal', 'irish metal', 'pagan black metal', 'symphonic black metal']
# Genres:  ['latin arena pop', 'latin pop', 'spanish pop rock']
# Genres:  ['deep christian rock']
# Genres:  ['brill building pop', 'classic girl group', 'motown', 'rock-and-roll']
# Genres:  ['chicago soul', 'classic soul', 'funk', 'soul']
# Genres:  ['new romantic', 'new wave pop', 'soft rock', 'sophisti-pop', 'synthpop']
# Genres:  []
# Genres:  ['acid jazz', 'brit funk', 'medway sound']
# Genres:  ['swamp rock']
# Batch completed at 10:58:58
# Processed 18 tracks in this batch
# Total tracks processed: 9874
# Last track processed: didnt know yet what id know when i was bleedin
# Last track genres: ['swamp rock']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 396 of 402
# Processing rows 9881 to 9906
# Genres:  []
# Genres:  ['christian alternative rock', 'christian music']
# Genres:  ['bakersfield sound', 'traditional country', 'western swing']
# Genres:  ['album rock', 'classic rock', 'country rock', 'folk rock', 'hard rock', 'heartland rock', 'mellow gold', 'rock', 'singer-songwriter', 'soft rock']
# Genres:  ['adult standards', 'brill building pop', 'merseybeat', 'rock-and-roll', 'rockabilly']
# Genres:  ['mambo', 'salsa']
# Genres:  ['israeli hip hop', 'jewish hip hop']
# Genres:  ['german alternative rap', 'hamburg hip hop', 'oldschool deutschrap']
# Genres:  ['indie extremena', 'spanish new wave', 'spanish pop', 'spanish pop rock']
# Genres:  ['industrial metal']
# Genres:  ['classical', 'german romanticism', 'post-romantic era']
# Genres:  []
# Genres:  ['british invasion']
# Genres:  ['album rock', 'mellow gold', 'new romantic', 'new wave', 'new wave pop', 'soft rock']
# Genres:  ['finnish death metal', 'finnish melodeath', 'finnish metal', 'folk metal', 'gothic metal', 'melodic death metal', 'metal', 'power metal', 'progressive doom', 'symphonic metal', 'viking metal']
# Genres:  ['experimental', 'experimental rock', 'outsider', 'protopunk', 'psychedelic rock', 'singer-songwriter', 'zolo']
# Genres:  ['british blues', 'progressive rock', 'proto-metal']
# Batch completed at 10:59:46
# Processed 17 tracks in this batch
# Total tracks processed: 9898
# Last track processed: los de aragxc3xb3n los de aragxc3xb3n
# Last track genres: ['british blues', 'progressive rock', 'proto-metal']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 397 of 402
# Processing rows 9906 to 9931
# Genres:  ['pop']
# Genres:  ['g funk', 'old school hip hop', 'west coast rap']
# Genres:  ['glam rock']
# Genres:  ['classic progressive house', 'downtempo', 'intelligent dance music']
# Genres:  ['easy listening', 'mambo']
# Genres:  ['prepared piano']
# Genres:  ['chicago soul', 'classic soul', 'quiet storm', 'rock-and-roll', 'soul']
# Genres:  ['buffalo ny metal', 'chaotic hardcore', 'melodic metalcore', 'post-hardcore', 'screamo']
# Genres:  []
# Genres:  ['beatdown', 'hardcore', 'straight edge']
# Genres:  ['classic girl group', 'classic soul', 'doo-wop', 'motown', 'rock-and-roll', 'soul']
# Genres:  ['c-pop', 'cantopop', 'classic cantopop']
# Genres:  ['neo mellow']
# Genres:  ['big room', 'dutch house', 'edm', 'electro house', 'melbourne bounce', 'pop dance', 'progressive electro house', 'progressive house']
# Batch completed at 11:00:35
# Processed 14 tracks in this batch
# Total tracks processed: 9920
# Last track processed: get up diplo mix
# Last track genres: ['big room', 'dutch house', 'edm', 'electro house', 'melbourne bounce', 'pop dance', 'progressive electro house', 'progressive house']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 398 of 402
# Processing rows 9931 to 9956
# Genres:  ['argentine punk', 'argentine rock']
# Genres:  ['vintage chanson', 'ye ye']
# Genres:  ['polish hip hop', 'polish old school hip hop']
# Genres:  ['jazz vibraphone']
# Genres:  ['ballroom', 'easy listening']
# Genres:  ['bubblegum pop', 'classic garage rock', 'classic rock', 'country rock', 'folk rock', 'mellow gold', 'merseybeat', 'psychedelic rock', 'rock-and-roll']
# Genres:  []
# Genres:  ['gothic black metal']
# Genres:  ['bossa nova', 'mpb', 'musica paraibana', 'samba']
# Genres:  ['cartoon', "children's music"]
# Genres:  []
# Genres:  ['greek contemporary classical', 'soundtrack']
# Genres:  ['cantopop']
# Genres:  []
# Genres:  ['contemporary country', 'country', 'country dawn', 'country road']
# Genres:  ['nashville sound', 'sunshine pop']
# Genres:  ['dance pop', 'pop', 'pop rap']
# Genres:  ['alternative rock', 'modern power pop', 'power pop', 'scottish indie', 'scottish rock', 'shoegaze']
# Batch completed at 11:01:24
# Processed 18 tracks in this batch
# Total tracks processed: 9949
# Last track processed: i dont know
# Last track genres: ['alternative rock', 'modern power pop', 'power pop', 'scottish indie', 'scottish rock', 'shoegaze']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 399 of 402
# Processing rows 9956 to 9981
# Genres:  ['canadian rock', 'country rock']
# Genres:  []
# Genres:  []
# Genres:  ['reggae', 'roots reggae']
# Genres:  ['neo mellow']
# HTTP Error for GET to https://api.spotify.com/v1/search with Params: {'q': 'track:anna bolena 1997 digital remaster alcun potria ascoltarti artist:maria callasgianni raimondigabriella carturanplinio clabassinicola rossilemenicoro del teatro alla scala_ milanonoberto molaorchestra del teatro alla scala_ milanogianandrea gavazzeni', 'limit': 1, 'offset': 0, 'type': 'track', 'market': None} returned 400 due to Query exceeds maximum length of 250 characters
# Error processing track anna bolena 1997 digital remaster alcun potria ascoltarti: http status: 400, code:-1 - https://api.spotify.com/v1/search?q=track%3Aanna+bolena+1997+digital+remaster+alcun+potria+ascoltarti+artist%3Amaria+callasgianni+raimondigabriella+carturanplinio+clabassinicola+rossilemenicoro+del+teatro+alla+scala_+milanonoberto+molaorchestra+del+teatro+alla+scala_+milanogianandrea+gavazzeni&limit=1&offset=0&type=track:
#  Query exceeds maximum length of 250 characters, reason: None
# Genres:  ['classic country pop', 'traditional country']
# Genres:  []
# Genres:  ['c-pop', 'classic mandopop']
# Genres:  ['orchestral soundtrack', 'soundtrack']
# Genres:  ['dance pop', 'pop', 'urban contemporary']
# Genres:  ['album rock', 'classic canadian rock', 'classic rock', 'glam metal', 'hard rock']
# Genres:  ['latin arena pop', 'latin pop', 'spanish pop', 'spanish pop rock']
# Genres:  []
# Genres:  ['spanish pop']
# Genres:  ['contemporary country', 'country', 'country dawn', 'country road']
# Genres:  ['abstract hip hop', 'alternative hip hop']
# Genres:  ['jump blues']
# Batch completed at 11:02:13
# Processed 17 tracks in this batch
# Total tracks processed: 9973
# Last track processed: save me rolling stone original version
# Last track genres: ['jump blues']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 400 of 402
# Processing rows 9981 to 10006
# Genres:  ['bossa nova', 'velha guarda']
# Genres:  ['brazilian indie', 'manguebeat', 'nova mpb']
# Genres:  ['easy listening']
# Genres:  ['chicano punk', 'crossover thrash', 'hardcore', 'hardcore punk', 'nyhc', 'old school thrash', 'punk']
# Genres:  ['melancholia']
# Genres:  ['el paso indie', 'garage rock']
# Genres:  ['norwegian house']
# Genres:  ['classic progressive house']
# Genres:  ['ambient psychill', 'psybass', 'psychill']
# Genres:  ['g funk', 'west coast rap']
# Genres:  ['alternative hip hop', 'hardcore hip hop', 'hip hop', 'jazz rap', 'west coast rap']
# Genres:  []
# Genres:  ['doom metal', 'groove metal', 'louisiana metal', 'sludge metal', 'southern metal']
# Genres:  []
# Genres:  []
# Batch completed at 11:03:01
# Processed 15 tracks in this batch
# Total tracks processed: 9996
# Last track processed: sarankxc3xa9gni
# Last track genres: No genres found
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 401 of 402
# Processing rows 10006 to 10031
# HTTP Error for GET to https://api.spotify.com/v1/search with Params: {'q': 'track:turandot 2008 digital remaster_ act iii scene i nessum dorma artist:maria callaseugenio fernandielisabeth schwarzkopfgiuseppe nessinicola zaccariamario borriellorenato ercolanipiero de palmagiulio maurielisabetta fuscopinuccia perotticoro del teatro alla scala_ milanoorchestra del teatro alla scala_ milanotul', 'limit': 1, 'offset': 0, 'type': 'track', 'market': None} returned 400 due to Query exceeds maximum length of 250 characters
# Genres:  ['classic country pop', 'honky tonk', 'traditional country', 'western swing']
# Error processing track turandot 2008 digital remaster_ act iii scene i nessum dorma: http status: 400, code:-1 - https://api.spotify.com/v1/search?q=track%3Aturandot+2008+digital+remaster_+act+iii+scene+i+nessum+dorma+artist%3Amaria+callaseugenio+fernandielisabeth+schwarzkopfgiuseppe+nessinicola+zaccariamario+borriellorenato+ercolanipiero+de+palmagiulio+maurielisabetta+fuscopinuccia+perotticoro+del+teatro+alla+scala_+milanoorchestra+del+teatro+alla+scala_+milanotul&limit=1&offset=0&type=track:
#  Query exceeds maximum length of 250 characters, reason: None
# Genres:  ['bhangra', 'classic pakistani pop', 'pakistani pop', 'sufi']
# Genres:  ['british soul', 'new wave pop']
# Genres:  ['deep soundtrack', 'soundtrack']
# Genres:  ['chanson']
# Genres:  ["man's orchestra"]
# Genres:  []
# Genres:  ['turntablism']
# Genres:  ['blues', 'boogie-woogie', 'louisiana blues', 'memphis blues', 'new orleans blues', 'new orleans soul', 'piano blues', 'traditional blues']
# Genres:  ['alternative rock', 'california hardcore', 'hardcore punk', 'punk']
# Genres:  ['rock drums', 'soft rock']
# Genres:  ['nashville sound']
# Genres:  ['family gospel', 'southern gospel']
# Genres:  ['colombian pop', 'latin pop', 'vallenato']
# Genres:  ['southern gospel']
# Batch completed at 11:03:51
# Processed 15 tracks in this batch
# Total tracks processed: 10021
# Last track processed: no soy uno mxc3xa1s
# Last track genres: ['southern gospel']
# Sleeping for 45 seconds...
# --------------------------------------------------
#
# Processing batch 402 of 402
# Processing rows 10031 to 10039
# Genres:  ['chakra', 'healing', 'high vibe', 'meditation', 'sleep']
# Genres:  ['classic country pop', 'cowboy western']
# Genres:  []
# Genres:  ['irish rock', 'permanent wave', 'rock']
# Genres:  []
# Genres:  ['manguebeat', 'nova mpb', 'nova musica pernambucana']
# Genres:  []
# Batch completed at 11:04:37
# Processed 7 tracks in this batch
# Total tracks processed: 10038
# Last track processed: souffle 2
# Last track genres: No genres found
#
# All batches processed!
# Final total tracks processed: 10038
